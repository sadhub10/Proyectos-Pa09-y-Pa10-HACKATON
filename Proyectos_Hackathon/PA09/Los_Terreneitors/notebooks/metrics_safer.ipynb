# %%
"""
Script para guardar las métricas del modelo después del entrenamiento
Ejecutar esto después de entrenar el modelo en el notebook 04
"""

import json
import os
from pathlib import Path

# Ajusta estos valores con los resultados de tu notebook 04
MODEL_METRICS = {
    "model_name": "SVM (optimizado)",
    "accuracy": 0.7477,  # Reemplazar con tu valor
    "f1_score": 0.7487,  # Reemplazar con tu valor
    "precision": 0.7554, # Reemplazar con tu valor
    "recall": 0.7477,    # Reemplazar con tu valor
    "training_samples": 39172,  # 80% de 48965
    "test_samples": 9793,       # 20% de 48965
    "total_samples": 48965,
    "n_categories": 4,
    "categories": ["Anxiety", "Depression", "Stress", "Suicidal"],
    "per_class_f1": {
        "Anxiety": 0.82,
        "Depression": 0.75,
        "Stress": 0.65,
        "Suicidal": 0.74
    }
}

# Guardar métricas
BASE_DIR = Path(__file__).resolve().parents[2]
METRICS_PATH = BASE_DIR / "src" / "models" / "saved" / "model_metrics.json"

os.makedirs(METRICS_PATH.parent, exist_ok=True)

with open(METRICS_PATH, 'w') as f:
    json.dump(MODEL_METRICS, f, indent=4)

print(f"✅ Métricas guardadas en: {METRICS_PATH}")
print(f"\n📊 Métricas del modelo:")
print(f"  Accuracy:  {MODEL_METRICS['accuracy']:.4f}")
print(f"  F1-Score:  {MODEL_METRICS['f1_score']:.4f}")
print(f"  Precision: {MODEL_METRICS['precision']:.4f}")
print(f"  Recall:    {MODEL_METRICS['recall']:.4f}")
